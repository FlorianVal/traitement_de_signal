# %%
import glob
import os
import librosa
import librosa.core
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
# %matplotlib inline
plt.style.use('ggplot')

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9
plt.rcParams['legend.fontsize'] = 11
plt.rcParams['figure.titlesize'] = 13

# %%
def windows(data, window_size):
    start = 0
    while start < len(data):
        yield int(start), int(start + window_size)
        start += (window_size / 2)

def extract_features(parent_dir,sub_dirs,file_ext="*.wav",bands = 60, frames = 41):
    window_size = 512 * (frames - 1)
    log_specgrams = []
    labels = []
    for l, sub_dir in enumerate(sub_dirs):
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)):
            sound_clip,s = librosa.load(fn)
            print(fn)
            label = fn.split('/')[2].split('-')[1].split(".")[0]
            for (start,end) in windows(sound_clip,window_size):
                if(len(sound_clip[start:end]) == window_size):
                    signal = sound_clip[start:end]
                    melspec = librosa.feature.melspectrogram(signal, n_mels = bands)
                    logspec = librosa.amplitude_to_db(melspec)
                    logspec = logspec.T.flatten()[:, np.newaxis].T
                    log_specgrams.append(logspec)
                    labels.append(label)
            
    log_specgrams = np.asarray(log_specgrams).reshape(len(log_specgrams),bands,frames,1)
    features = np.concatenate((log_specgrams, np.zeros(np.shape(log_specgrams))), axis = 3)
    for i in range(len(features)):
        features[i, :, :, 1] = librosa.feature.delta(features[i, :, :, 0])
    
    return np.array(features), np.array(labels,dtype = np.int)

def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1
    return one_hot_encode

# %%
parent_dir = 'data'
sub_dirs= ['Cryingbaby','else']
features,labels = extract_features(parent_dir,sub_dirs)
labels = one_hot_encode(labels)
# Out:
# data/Cryingbaby/Cryingbaby-0-13.wav
# data/Cryingbaby/Cryingbaby-0-4.wav
# data/Cryingbaby/Cryingbaby-0-5.wav
# data/Cryingbaby/Cryingbaby-0-12.wav
# data/Cryingbaby/Cryingbaby-0-10.wav
# data/Cryingbaby/Cryingbaby-0-38.wav
# data/Cryingbaby/Cryingbaby-0-7.wav
# data/Cryingbaby/Cryingbaby-0-6.wav
# data/Cryingbaby/Cryingbaby-0-39.wav
# data/Cryingbaby/Cryingbaby-0-11.wav
# data/Cryingbaby/Cryingbaby-0-29.wav
# data/Cryingbaby/Cryingbaby-0-15.wav
# data/Cryingbaby/Cryingbaby-0-2.wav
# data/Cryingbaby/Cryingbaby-0-3.wav
# data/Cryingbaby/Cryingbaby-0-14.wav
# data/Cryingbaby/Cryingbaby-0-28.wav
# data/Cryingbaby/Cryingbaby-0-16.wav
# data/Cryingbaby/Cryingbaby-0-1.wav
# data/Cryingbaby/Cryingbaby-0-17.wav
# data/Cryingbaby/Cryingbaby-0-64.wav
# data/Cryingbaby/Cryingbaby-0-58.wav
# data/Cryingbaby/Cryingbaby-0-59.wav
# data/Cryingbaby/Cryingbaby-0-65.wav
# data/Cryingbaby/Cryingbaby-0-67.wav
# data/Cryingbaby/Cryingbaby-0-66.wav
# data/Cryingbaby/Cryingbaby-0-62.wav
# data/Cryingbaby/Cryingbaby-0-63.wav
# data/Cryingbaby/Cryingbaby-0-49.wav
# data/Cryingbaby/Cryingbaby-0-61.wav
# data/Cryingbaby/Cryingbaby-0-60.wav
# data/Cryingbaby/Cryingbaby-0-48.wav
# data/Cryingbaby/Cryingbaby-0-45.wav
# data/Cryingbaby/Cryingbaby-0-51.wav
# data/Cryingbaby/Cryingbaby-0-50.wav
# data/Cryingbaby/Cryingbaby-0-44.wav
# data/Cryingbaby/Cryingbaby-0-52.wav
# data/Cryingbaby/Cryingbaby-0-46.wav
# data/Cryingbaby/Cryingbaby-0-47.wav
# data/Cryingbaby/Cryingbaby-0-53.wav
# data/Cryingbaby/Cryingbaby-0-57.wav
# data/Cryingbaby/Cryingbaby-0-43.wav
# data/Cryingbaby/Cryingbaby-0-42.wav
# data/Cryingbaby/Cryingbaby-0-56.wav
# data/Cryingbaby/Cryingbaby-0-68.wav
# data/Cryingbaby/Cryingbaby-0-40.wav
# data/Cryingbaby/Cryingbaby-0-54.wav
# data/Cryingbaby/Cryingbaby-0-55.wav
# data/Cryingbaby/Cryingbaby-0-41.wav
# data/Cryingbaby/Cryingbaby-0-26.wav
# data/Cryingbaby/Cryingbaby-0-32.wav
# data/Cryingbaby/Cryingbaby-0-33.wav
# data/Cryingbaby/Cryingbaby-0-27.wav
# data/Cryingbaby/Cryingbaby-0-31.wav
# data/Cryingbaby/Cryingbaby-0-25.wav
# data/Cryingbaby/Cryingbaby-0-19.wav
# data/Cryingbaby/Cryingbaby-0-18.wav
# data/Cryingbaby/Cryingbaby-0-24.wav
# data/Cryingbaby/Cryingbaby-0-30.wav
# data/Cryingbaby/Cryingbaby-0-34.wav
# data/Cryingbaby/Cryingbaby-0-20.wav
# data/Cryingbaby/Cryingbaby-0-21.wav
# data/Cryingbaby/Cryingbaby-0-35.wav
# data/Cryingbaby/Cryingbaby-0-23.wav
# data/Cryingbaby/Cryingbaby-0-37.wav
# data/Cryingbaby/Cryingbaby-0-8.wav
# data/Cryingbaby/Cryingbaby-0-9.wav
# data/Cryingbaby/Cryingbaby-0-36.wav
# data/Cryingbaby/Cryingbaby-0-22.wav
# data/else/else-1-29.wav
# data/else/else-1-15.wav
# data/else/else-1-109.wav
# data/else/else-1-135.wav
# data/else/else-1-121.wav
# data/else/else-1-120.wav
# data/else/else-1-134.wav
# data/else/else-1-108.wav
# data/else/else-1-14.wav
# data/else/else-1-28.wav
# data/else/else-1-16.wav
# data/else/else-1-122.wav
# data/else/else-1-136.wav
# data/else/else-1-137.wav
# data/else/else-1-123.wav
# data/else/else-1-17.wav
# data/else/else-1-13.wav
# data/else/else-1-127.wav
# data/else/else-1-133.wav
# data/else/else-1-8.wav
# data/else/else-1-9.wav
# data/else/else-1-132.wav
# data/else/else-1-126.wav
# data/else/else-1-12.wav
# data/else/else-1-10.wav
# data/else/else-1-38.wav
# data/else/else-1-130.wav
# data/else/else-1-124.wav
# data/else/else-1-118.wav
# data/else/else-1-119.wav
# data/else/else-1-125.wav
# data/else/else-1-131.wav
# data/else/else-1-39.wav
# data/else/else-1-11.wav
# data/else/else-1-89.wav
# data/else/else-1-62.wav
# data/else/else-1-76.wav
# data/else/else-1-156.wav
# data/else/else-1-142.wav
# data/else/else-1-195.wav
# data/else/else-1-181.wav
# data/else/else-1-208.wav
# data/else/else-1-209.wav
# data/else/else-1-180.wav
# data/else/else-1-194.wav
# data/else/else-1-143.wav
# data/else/else-1-157.wav
# data/else/else-1-77.wav
# data/else/else-1-63.wav
# data/else/else-1-88.wav
# data/else/else-1-49.wav
# data/else/else-1-75.wav
# data/else/else-1-61.wav
# data/else/else-1-169.wav
# data/else/else-1-141.wav
# data/else/else-1-155.wav
# data/else/else-1-182.wav
# data/else/else-1-196.wav
# data/else/else-1-197.wav
# data/else/else-1-183.wav
# data/else/else-1-154.wav
# data/else/else-1-140.wav
# data/else/else-1-168.wav
# data/else/else-1-60.wav
# data/else/else-1-74.wav
# data/else/else-1-48.wav
# data/else/else-1-70.wav
# data/else/else-1-64.wav
# data/else/else-1-58.wav
# data/else/else-1-144.wav
# data/else/else-1-150.wav
# data/else/else-1-178.wav
# data/else/else-1-187.wav
# data/else/else-1-193.wav
# data/else/else-1-192.wav
# data/else/else-1-186.wav
# data/else/else-1-179.wav
# data/else/else-1-151.wav
# data/else/else-1-145.wav
# data/else/else-1-59.wav
# data/else/else-1-65.wav
# data/else/else-1-71.wav
# data/else/else-1-98.wav
# data/else/else-1-67.wav
# data/else/else-1-73.wav
# data/else/else-1-153.wav
# data/else/else-1-147.wav
# data/else/else-1-190.wav
# data/else/else-1-184.wav
# data/else/else-1-185.wav
# data/else/else-1-191.wav
# data/else/else-1-146.wav
# data/else/else-1-152.wav
# data/else/else-1-72.wav
# data/else/else-1-66.wav
# data/else/else-1-99.wav
# data/else/else-1-80.wav
# data/else/else-1-94.wav
# data/else/else-1-43.wav
# data/else/else-1-57.wav
# data/else/else-1-177.wav
# data/else/else-1-163.wav
# data/else/else-1-188.wav
# data/else/else-1-201.wav
# data/else/else-1-215.wav
# data/else/else-1-214.wav
# data/else/else-1-200.wav
# data/else/else-1-189.wav
# data/else/else-1-162.wav
# data/else/else-1-176.wav
# data/else/else-1-56.wav
# data/else/else-1-42.wav
# data/else/else-1-95.wav
# data/else/else-1-81.wav
# data/else/else-1-97.wav
# data/else/else-1-83.wav
# data/else/else-1-68.wav
# data/else/else-1-54.wav
# data/else/else-1-40.wav
# data/else/else-1-148.wav
# data/else/else-1-160.wav
# data/else/else-1-174.wav
# data/else/else-1-216.wav
# data/else/else-1-202.wav
# data/else/else-1-203.wav
# data/else/else-1-175.wav
# data/else/else-1-161.wav
# data/else/else-1-149.wav
# data/else/else-1-41.wav
# data/else/else-1-55.wav
# data/else/else-1-69.wav
# data/else/else-1-82.wav
# data/else/else-1-96.wav
# data/else/else-1-92.wav
# data/else/else-1-86.wav
# data/else/else-1-51.wav
# data/else/else-1-45.wav
# data/else/else-1-79.wav
# data/else/else-1-165.wav
# data/else/else-1-171.wav
# data/else/else-1-159.wav
# data/else/else-1-213.wav
# data/else/else-1-207.wav
# data/else/else-1-206.wav
# data/else/else-1-212.wav
# data/else/else-1-158.wav
# data/else/else-1-170.wav
# data/else/else-1-164.wav
# data/else/else-1-78.wav
# data/else/else-1-44.wav
# data/else/else-1-50.wav
# data/else/else-1-87.wav
# data/else/else-1-93.wav
# data/else/else-1-85.wav
# data/else/else-1-91.wav
# data/else/else-1-46.wav
# data/else/else-1-52.wav
# data/else/else-1-172.wav
# data/else/else-1-166.wav
# data/else/else-1-199.wav
# data/else/else-1-204.wav
# data/else/else-1-210.wav
# data/else/else-1-211.wav
# data/else/else-1-205.wav
# data/else/else-1-198.wav
# data/else/else-1-167.wav
# data/else/else-1-173.wav
# data/else/else-1-53.wav
# data/else/else-1-47.wav
# data/else/else-1-90.wav
# data/else/else-1-84.wav
# data/else/else-1-20.wav
# data/else/else-1-34.wav
# data/else/else-1-128.wav
# data/else/else-1-114.wav
# data/else/else-1-100.wav
# data/else/else-1-7.wav
# data/else/else-1-6.wav
# data/else/else-1-101.wav
# data/else/else-1-115.wav
# data/else/else-1-129.wav
# data/else/else-1-35.wav
# data/else/else-1-21.wav
# data/else/else-1-37.wav
# data/else/else-1-23.wav
# data/else/else-1-103.wav
# data/else/else-1-117.wav
# data/else/else-1-4.wav
# data/else/else-1-5.wav
# data/else/else-1-116.wav
# data/else/else-1-102.wav
# data/else/else-1-22.wav
# data/else/else-1-36.wav
# data/else/else-1-32.wav
# data/else/else-1-26.wav
# data/else/else-1-106.wav
# data/else/else-1-112.wav
# data/else/else-1-1.wav
# data/else/else-1-113.wav
# data/else/else-1-107.wav
# data/else/else-1-27.wav
# data/else/else-1-33.wav
# data/else/else-1-25.wav
# data/else/else-1-31.wav
# data/else/else-1-19.wav
# data/else/else-1-111.wav
# data/else/else-1-105.wav
# data/else/else-1-139.wav
# data/else/else-1-2.wav
# data/else/else-1-3.wav
# data/else/else-1-138.wav
# data/else/else-1-104.wav
# data/else/else-1-110.wav
# data/else/else-1-18.wav
# data/else/else-1-30.wav
# data/else/else-1-24.wav

# %%
import os
path = "data/else/"
files = os.listdir(path)
index =0
for file in files:
    if file.split(".")[-1] =="wav":
        index +=1
        os.rename(path +"/"+ file,f"{path}/else-1-{index}.wav")
        print(file)
        if index ==68:
            break
print(files)
# Out:
# laugh_1.m4a_68.wav
# laugh_1.m4a_40.wav
# laugh_1.m4a_54.wav
# laugh_1.m4a_5.wav
# laugh_1.m4a_83.wav
# silence.wav_21.wav
# silence.wav_35.wav
# silence.wav_34.wav
# silence.wav_20.wav
# laugh_1.m4a_82.wav
# laugh_1.m4a_4.wav
# laugh_1.m4a_55.wav
# laugh_1.m4a_41.wav
# laugh_1.m4a_69.wav
# laugh_1.m4a_57.wav
# laugh_1.m4a_43.wav
# laugh_1.m4a_6.wav
# laugh_1.m4a_80.wav
# silence.wav_36.wav
# silence.wav_22.wav
# silence.wav_23.wav
# silence.wav_37.wav
# laugh_1.m4a_81.wav
# laugh_1.m4a_7.wav
# laugh_1.m4a_42.wav
# laugh_1.m4a_56.wav
# laugh_1.m4a_52.wav
# laugh_1.m4a_46.wav
# laugh_1.m4a_85.wav
# laugh_1.m4a_3.wav
# silence.wav_33.wav
# silence.wav_27.wav
# silence.wav_26.wav
# silence.wav_32.wav
# laugh_1.m4a_2.wav
# laugh_1.m4a_84.wav
# laugh_1.m4a_47.wav
# laugh_1.m4a_53.wav
# laugh_1.m4a_45.wav
# laugh_1.m4a_51.wav
# laugh_1.m4a_79.wav
# laugh_1.m4a_86.wav
# laugh_1.m4a_0.wav
# laugh_2.m4a_8.wav
# silence.wav_18.wav
# silence.wav_24.wav
# silence.wav_30.wav
# silence.wav_31.wav
# silence.wav_25.wav
# silence.wav_19.wav
# laugh_2.m4a_9.wav
# laugh_1.m4a_1.wav
# laugh_1.m4a_87.wav
# laugh_1.m4a_78.wav
# laugh_1.m4a_50.wav
# laugh_1.m4a_44.wav
# laugh_1.m4a_23.wav
# laugh_1.m4a_37.wav
# laugh_2.m4a_11.wav
# silence.wav_42.wav
# silence.wav_56.wav
# silence.wav_81.wav
# silence.wav_95.wav
# silence.wav_102.wav
# silence.wav_103.wav
# silence.wav_94.wav
# silence.wav_80.wav
# silence.wav_57.wav
# ['laugh_1.m4a_68.wav', 'laugh_1.m4a_40.wav', 'laugh_1.m4a_54.wav', 'laugh_1.m4a_5.wav', 'laugh_1.m4a_83.wav', '2-59565-A.ogg', '4-223127-A.ogg', '1-47819-C.ogg', 'silence.wav_21.wav', 'silence.wav_35.wav', '3-203375-A.ogg', '3-155130-A.ogg', 'silence.wav_34.wav', 'silence.wav_20.wav', '1-47819-B.ogg', '2-56926-A.ogg', 'laugh_1.m4a_82.wav', 'laugh_1.m4a_4.wav', 'laugh_1.m4a_55.wav', 'laugh_1.m4a_41.wav', 'laugh_1.m4a_69.wav', 'laugh_1.m4a_57.wav', '1-56907-A.ogg', '3-161010-A.ogg', 'laugh_1.m4a_43.wav', 'laugh_1.m4a_6.wav', 'laugh_1.m4a_80.wav', '2-114280-A.ogg', 'silence.wav_36.wav', 'silence.wav_22.wav', '2-144137-A.ogg', '5-243448-A.ogg', '5-242491-A.ogg', '3-203377-A.ogg', 'silence.wav_23.wav', 'silence.wav_37.wav', '1-47819-A.ogg', '2-138465-A.ogg', 'laugh_1.m4a_81.wav', 'laugh_1.m4a_7.wav', '4-223125-A.ogg', 'laugh_1.m4a_42.wav', 'laugh_1.m4a_56.wav', '5-192191-A.ogg', 'laugh_1.m4a_52.wav', 'laugh_1.m4a_46.wav', '3-203373-A.ogg', '1-13572-A.ogg', 'laugh_1.m4a_85.wav', 'laugh_1.m4a_3.wav', '4-184235-A.ogg', '1-34094-A.ogg', 'silence.wav_33.wav', 'silence.wav_27.wav', '3-151557-B.ogg', 'silence.wav_26.wav', 'silence.wav_32.wav', 'laugh_1.m4a_2.wav', 'laugh_1.m4a_84.wav', 'laugh_1.m4a_47.wav', 'laugh_1.m4a_53.wav', 'laugh_1.m4a_45.wav', 'laugh_1.m4a_51.wav', 'laugh_1.m4a_79.wav', 'laugh_1.m4a_86.wav', 'laugh_1.m4a_0.wav', 'laugh_2.m4a_8.wav', '3-216281-A.ogg', 'silence.wav_18.wav', '1-34094-B.ogg', 'silence.wav_24.wav', 'silence.wav_30.wav', '3-58772-A.ogg', '3-151557-A.ogg', 'silence.wav_31.wav', 'silence.wav_25.wav', 'silence.wav_19.wav', 'laugh_2.m4a_9.wav', '3-203371-A.ogg', '1-30344-A.ogg', 'laugh_1.m4a_1.wav', 'laugh_1.m4a_87.wav', 'laugh_1.m4a_78.wav', 'laugh_1.m4a_50.wav', 'laugh_1.m4a_44.wav', 'laugh_1.m4a_23.wav', 'laugh_1.m4a_37.wav', '5-243449-A.ogg', 'laugh_2.m4a_11.wav', '1-54747-A.ogg', 'silence.wav_42.wav', 'silence.wav_56.wav', 'silence.wav_81.wav', 'silence.wav_95.wav', '2-82274-B.ogg', '3-51909-B.ogg', 'silence.wav_102.wav', '5-156999-E.ogg', '2-128465-B.ogg', '1-56380-A.ogg', '5-156999-D.ogg', 'silence.wav_103.wav', '1-30226-A.ogg', '2-59566-A.ogg', 'silence.wav_94.wav', 'silence.wav_80.wav', 'silence.wav_57.wav', '5-243450-A.ogg', 'silence.wav_43.wav', 'laugh_2.m4a_10.wav', '5-242490-A.ogg', '3-146697-A.ogg', 'laugh_1.m4a_36.wav', 'laugh_1.m4a_22.wav', '3-130998-A.ogg', '3-203374-A.ogg', 'laugh_1.m4a_34.wav', 'laugh_1.m4a_20.wav', '2-72688-A.ogg', 'laugh_2.m4a_12.wav', 'silence.wav_55.wav', 'silence.wav_41.wav', 'silence.wav_69.wav', 'silence.wav_96.wav', '2-82274-A.ogg', 'silence.wav_82.wav', '3-51909-A.ogg', 'silence.wav_101.wav', '3-174840-A.ogg', '2-128465-A.ogg', '4-204115-A.ogg', 'silence.wav_100.wav', '1-56380-B.ogg', 'silence.wav_83.wav', 'silence.wav_97.wav', 'silence.wav_68.wav', 'silence.wav_40.wav', 'silence.wav_54.wav', 'laugh_2.m4a_13.wav', '3-216284-A.ogg', 'laugh_1.m4a_21.wav', 'laugh_1.m4a_35.wav', '2-117271-A.ogg', '3-130998-B.ogg', 'laugh_1.m4a_31.wav', 'laugh_1.m4a_25.wav', 'laugh_1.m4a_19.wav', '3-51376-A.ogg', 'laugh_2.m4a_17.wav', 'silence.wav_78.wav', 'silence.wav_50.wav', 'silence.wav_44.wav', '3-216280-A.ogg', 'silence.wav_93.wav', 'silence.wav_87.wav', '3-155234-A.ogg', '2-116400-A.ogg', 'silence.wav_104.wav', '5-156999-C.ogg', '5-156999-B.ogg', 'silence.wav_105.wav', 'silence.wav_86.wav', 'silence.wav_92.wav', '1-13571-A.ogg', 'silence.wav_45.wav', 'silence.wav_51.wav', 'silence.wav_79.wav', 'laugh_2.m4a_16.wav', 'laugh_1.m4a_18.wav', 'laugh_1.m4a_24.wav', 'laugh_1.m4a_30.wav', 'laugh_1.m4a_26.wav', 'laugh_1.m4a_32.wav', '4-187769-B.ogg', '3-153057-A.ogg', 'silence.wav_8.wav', 'laugh_2.m4a_14.wav', 'silence.wav_47.wav', 'silence.wav_53.wav', 'silence.wav_84.wav', 'silence.wav_90.wav', 'silence.wav_107.wav', '5-156999-A.ogg', 'silence.wav_106.wav', 'silence.wav_91.wav', '4-161519-A.ogg', 'silence.wav_85.wav', 'silence.wav_52.wav', 'silence.wav_46.wav', 'laugh_2.m4a_15.wav', '2-70936-A.ogg', 'silence.wav_9.wav', 'laugh_1.m4a_33.wav', 'laugh_1.m4a_27.wav', 'laugh_1.m4a_16.wav', ' ...

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(1.0, shape = shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x,W,strides=[1,2,2,1], padding='SAME')

def apply_convolution(x,kernel_size,num_channels,depth):
    weights = weight_variable([kernel_size, kernel_size, num_channels, depth])
    biases = bias_variable([depth])
    return tf.nn.relu(tf.add(conv2d(x, weights),biases))

def apply_max_pool(x,kernel_size,stride_size):
    return tf.nn.max_pool(x, ksize=[1, kernel_size, kernel_size, 1], 
                          strides=[1, stride_size, stride_size, 1], padding='SAME')

# %%
rnd_indices = np.random.rand(len(labels)) < 0.70

train_x = features[rnd_indices]
train_y = labels[rnd_indices]
test_x = features[~rnd_indices]
test_y = labels[~rnd_indices]

# %%
frames = 41
bands = 60

feature_size = 2460 #60x41
num_labels = 2
num_channels = 2

batch_size = 20
kernel_size = 50
depth = 20
num_hidden = 400

learning_rate = 0.005
training_iterations = 200

# %%
X = tf.placeholder(tf.float32, shape=[None,bands,frames,num_channels])
Y = tf.placeholder(tf.float32, shape=[None,num_labels])

cov = apply_convolution(X,kernel_size,num_channels,depth)

shape = cov.get_shape().as_list()
cov_flat = tf.reshape(cov, [-1, shape[1] * shape[2] * shape[3]])

f_weights = weight_variable([shape[1] * shape[2] * depth, num_hidden])
f_biases = bias_variable([num_hidden])
f = tf.nn.sigmoid(tf.add(tf.matmul(cov_flat, f_weights),f_biases))

out_weights = weight_variable([num_hidden, num_labels])
out_biases = bias_variable([num_labels])
y_ = tf.nn.softmax(tf.matmul(f, out_weights) + out_biases)

# %%
cross_entropy = -tf.reduce_sum(Y * tf.log(y_))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
cost_history = np.empty(shape=[1],dtype=float)
with tf.Session() as session:
    tf.global_variables_initializer().run()

    for itr in range(training_iterations):    
        offset = (itr * batch_size) % (train_y.shape[0] - batch_size)
        batch_x = train_x[offset:(offset + batch_size), :, :, :]
        batch_y = train_y[offset:(offset + batch_size), :]
        
        _, c = session.run([optimizer, cross_entropy],feed_dict={X: batch_x, Y : batch_y})
        cost_history = np.append(cost_history,c)
        if itr%10 == 0:
            print(round(session.run(accuracy, feed_dict={X: test_x, Y: test_y}) , 3))
    
    print('Test accuracy: ',round(session.run(accuracy, feed_dict={X: test_x, Y: test_y}) , 3))
    fig = plt.figure(figsize=(15,10))
    plt.plot(cost_history)
    plt.axis([0,training_iterations,0,np.max(cost_history)])
    plt.show()
# Out:
# 0.264
# 0.264
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-50f77b732899> in <module>
#       8         batch_y = train_y[offset:(offset + batch_size), :]
#       9
# ---> 10         _, c = session.run([optimizer, cross_entropy],feed_dict={X: batch_x, Y : batch_y})
#      11         cost_history = np.append(cost_history,c)
#      12         if itr%10 == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
